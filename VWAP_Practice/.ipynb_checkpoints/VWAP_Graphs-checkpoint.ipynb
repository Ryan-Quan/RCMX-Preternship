# %%
import mplfinance as mpf
import pandas as pd
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt

# %%
API_key = 'MCO3JQL81ATB1YZ0'
time = TimeSeries(key = API_key,output_format='pandas')

# %%
ticker = 'TSLA'
data = time.get_intraday(symbol=ticker,interval='1min',outputsize='full')

# %%
df = data[0]
df = df.rename(columns={"1. open":"Open","2. high":"High","3. low":"Low","4. close":"Close","5. volume":"Volume"})
result = [group[1] for group in df.groupby(df.index.day)]

# %%
for df_vwap in result:
    df_vwap = df_vwap.loc[(df_vwap.index.hour >= 9)]
    df_vwap = df_vwap.loc[(df_vwap.index.hour <= 15)]
    df_vwap = df_vwap.resample('5T').agg({'Open':'first','High':'max','Low':'min','Close':'last','Volume':'sum'})
    df_vwap['VWAP'] = (((df_vwap['High']+df_vwap['Low']+df_vwap['Close'])*df_vwap['Volume']/3).cumsum())/df_vwap['Volume'].cumsum()
    df_vwap['TWAP'] = ((df_vwap['Open'] + df_vwap['High']+df_vwap['Low'] + df_vwap['Close'])/4)
    df_vwap = df_vwap.dropna()
    vwap = mpf.make_addplot(df_vwap['VWAP'])
    mpf.plot(df_vwap,addplot=vwap,type='candle',style='yahoo',volume=True,title=f"{df_vwap.index.date[0]} {ticker} VWAP")
    strategy1(df_vwap,1000)
# Out:
# 2021-04-14
# 09:00:00: Buy 1.287 TSLA shares at 777.25 per share
# 09:15:00: Sell 1.287 TSLA shares at 772.6115 per share
# 09:35:00: Buy 1.287 TSLA shares at 772.0875 per share
# 09:50:00: Sell 1.287 TSLA shares at 771.1399 per share
# 12:40:00: Buy 1.303 TSLA shares at 761.8115 per share
# 12:55:00: Sell 1.303 TSLA shares at 758.62 per share
# Cash: 988.6529229475626
# Return: -1.13%
# 2021-04-15
# 09:10:00: Buy 1.347 TSLA shares at 742.49 per share
# 09:15:00: Sell 1.347 TSLA shares at 742.02 per share
# 09:25:00: Buy 1.345 TSLA shares at 743.0 per share
# 09:30:00: Sell 1.345 TSLA shares at 738.59 per share
# 10:25:00: Buy 1.358 TSLA shares at 731.3063 per share
# 11:25:00: Sell 1.358 TSLA shares at 729.63 per share
# 12:35:00: Buy 1.355 TSLA shares at 731.751 per share
# 12:45:00: Sell 1.355 TSLA shares at 729.885 per share
# 12:50:00: Buy 1.351 TSLA shares at 731.695 per share
# 12:55:00: Sell 1.351 TSLA shares at 729.9704 per share
# 13:55:00: Buy 1.343 TSLA shares at 734.205 per share
# Cash: 992.1105318053532
# Return: -0.79%
# 2021-04-16
# 09:40:00: Buy 1.368 TSLA shares at 730.8994 per share
# 09:50:00: Sell 1.368 TSLA shares at 727.0506 per share
# 10:05:00: Buy 1.362 TSLA shares at 730.4013 per share
# 10:30:00: Sell 1.362 TSLA shares at 729.4269 per share
# 10:40:00: Buy 1.359 TSLA shares at 730.795 per share
# Cash: 1005.4849590124494
# Return: 0.55%
# 2021-04-19
# 09:05:00: Buy 1.384 TSLA shares at 722.37 per share
# 09:10:00: Sell 1.384 TSLA shares at 720.48 per share
# 09:20:00: Buy 1.383 TSLA shares at 721.28 per share
# 09:25:00: Sell 1.383 TSLA shares at 719.0 per share
# 11:05:00: Buy 1.408 TSLA shares at 706.04 per share
# 14:35:00: Sell 1.408 TSLA shares at 707.7175 per share
# 14:40:00: Buy 1.407 TSLA shares at 708.16 per share
# Cash: 1004.0798885221045
# Return: 0.41%
# 2021-04-20
# 09:05:00: Buy 1.407 TSLA shares at 710.658 per share
# 10:40:00: Sell 1.407 TSLA shares at 726.91 per share
# Cash: 1022.8689468070435
# Return: 2.29%
# 2021-04-21
# 09:00:00: Buy 1.405 TSLA shares at 711.59 per share
# 09:20:00: Sell 1.405 TSLA shares at 709.1326 per share
# 09:45:00: Buy 1.415 TSLA shares at 704.505 per share
# Cash: 1051.409326319264
# Return: 5.14%
# 2021-04-22
# 09:00:00: Buy 1.346 TSLA shares at 743.05 per share
# 09:15:00: Sell 1.346 TSLA shares at 744.02 per share
# 09:30:00: Buy 1.332 TSLA shares at 751.68 per share
# 09:40:00: Sell 1.332 TSLA shares at 746.56 per share
# 10:05:00: Buy 1.334 TSLA shares at 745.39 per share
# 10:10:00: Sell 1.334 TSLA shares at 741.68 per share
# 10:50:00: Buy 1.330 TSLA shares at 744.17 per share
# 10:55:00: Sell 1.330 TSLA shares at 742.1568 per share
# 12:35:00: Buy 1.328 TSLA shares at 743.24 per share
# 13:05:00: Sell 1.328 TSLA shares at 736.18 per share
# Cash: 977.4842138483164
# Return: -2.25%
# 2021-04-23
# 09:00:00: Buy 1.386 TSLA shares at 721.4 per share
# 09:05:00: Sell 1.386 TSLA shares at 718.89 per share
# 09:25:00: Buy 1.385 TSLA shares at 719.72 per share
# 09:30:00: Sell 1.385 TSLA shares at 717.47 per share
# 09:35:00: Buy 1.376 TSLA shares at 722.1525 per share
# 14:00:00: Sell 1.376 TSLA shares at 729.3492 per share
# 15:10:00: Buy 1.376 TSLA shares at 729.27 per share
# 15:15:00: Sell 1.376 TSLA shares at 728.54 per share
# 15:20:00: Buy 1.374 TSLA shares at 729.4385 per share
# 15:40:00: Sell 1.374 TSLA shares at 728.82 per share
# 15:50:00: Buy 1.373 TSLA shares at 729.17 per share
# Cash: 1001.8493357796534
# Return: 0.18%
# 2021-04-26
# 09:00:00: Buy 1.349 TSLA shares at 741.03 per share
# 09:10:00: Sell 1.349 TSLA shares at 740.8 per share
# 09:25:00: Buy 1.349 TSLA shares at 741.0 per share
# 09:40:00: Sell 1.349 TSLA shares at 744.39 per share
# 11:25:00: Buy 1.358 TSLA shares at 739.77 per share
# 11:45:00: Sell 1.358 TSLA shares at 738.34 per share
# 12:20:00: Buy 1.356 TSLA shares at 739.2477 per share
# 12:25:00: Sell 1.356 TSLA shares at 738.065 per share
# 12:35:00: Buy 1.353 TSLA shares at 739.52 per share
# 12:40:00: Sell 1.353 TSLA shares at 738.4506 per share
# 12:45:00: Buy 1.350 TSLA shares at 740.02 per share
# 12:50:00: Sell 1.350 TSLA shares at 738.645 per share
# 13:00:00: Buy 1.349 TSLA shares at 739.115 per share
# 13:05:00: Sell 1.349 TSLA shares at 737.45 per share
# 15:25:00: Buy 1.345 TSLA shares at 740.095 per share
# 15:30:00: Sell 1.345 TSLA shares at 736.31 per share
# Cash: 990.0780626078731
# Return: -0.99%
# 2021-04-27
# 09:05:00: Buy 1.393 TSLA shares at 717.9 per share
# 09:30:00: Sell 1.393 TSLA shares at 717.82 per share
# 09:35:00: Buy 1.384 TSLA shares at 722.21 per share
# 09:40:00: Sell 1.384 TSLA shares at 717.8199 per share
# 11:20:00: Buy 1.394 TSLA shares at 713.1 per share
# 12:10:00: Sell 1.394 TSLA shares at 712.11 per share
# 12:15:00: Buy 1.392 TSLA shares at 713.09 per share
# 12:35:00: Sell 1.392 TSLA shares at 712.0981 per share
# 12:40:00: Buy 1.390 TSLA shares at 713.1047 per share
# 12:55:00: Sell 1.390 TSLA shares at 710.18 per share
# Cash: 986.985711180728
# Return: -1.30%

# %%
def strategy1(df_vwap,cash):
    shares = 0
    cash0 = cash
    print(f'{df_vwap.index.date[0]}')
    for index,row in df_vwap.iterrows():
        if ((row['VWAP'] < row['Close']) and cash):
            shares = cash/row['Close']
            print(f"{index.time()}: Buy {shares:.3f} {ticker} shares at {row['Close']} per share")
            cash = 0
        if ((row['VWAP'] > row['Close']) and not cash):
            cash = shares*row['Close']
            print(f"{index.time()}: Sell {shares:.3f} {ticker} shares at {row['Close']} per share")
            shares = 0
        price = row['Close']
    cash = cash + shares*price
    print(f'Cash: {cash}')
    print(f'Return: {((cash - cash0)/cash0)*100:.2f}%')
    return
